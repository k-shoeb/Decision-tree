# %% [markdown]
# ## Data science and Buisiness Analytics Internship at The Sparks Foundation
# ### Task 3: Prediction using Decision Tree Algorithm
# #### In this task we have to Predict the Species of Iris flower based on the length and width of its Sepals and Petals.
# *- By Khan Shoeb*

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, plot_confusion_matrix

# %%
# Download file into workspace
iris_url = "https://bit.ly/3VWMJZw"
iris_df= pd.read_csv(iris_url)
print("Data imported successfully")
# Out:
# Data imported successfully

# %%
# Read First Five rows
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Delete Id column as it is not required
iris_df.drop('Id', axis= 1 , inplace = True) 
iris_df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# No. of rows and columns in the dataset
iris_df.shape
# Out:
# (150, 5)

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
# Check for any null value
iris_df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# Check for duplicate data
dupl=iris_df.duplicated()
print('No. of duplicate rows is', dupl.sum())
iris_df[dupl]
# Out:
# No. of duplicate rows is 3
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 34             4.9           3.1            1.5           0.1     Iris-setosa
# 37             4.9           3.1            1.5           0.1     Iris-setosa
# 142            5.8           2.7            5.1           1.9  Iris-virginica

# %%
# Delete duplicate rows
iris_df.drop_duplicates(inplace=True) 
print(iris_df.duplicated().sum(), 'duplicate rows')
# Out:
# 0 duplicate rows

# %%
# No. of rows and columns after deleting duplicates
iris_df.shape
# Out:
# (147, 5)

# %%
# No. of data for each types of species 
iris_df.Species.value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     49
# Iris-setosa        48
# Name: Species, dtype: int64

# %%
# Unique values in each atributes

petal_width = iris_df["PetalWidthCm"].unique()
print("There are",len(petal_width),"unique petal width values.")

petal_length = iris_df["PetalLengthCm"].unique()
print("There are",len(petal_length),"unique petal lenght values.")

sepal_width = iris_df["SepalWidthCm"].unique()
print("There are",len(sepal_width),"unique sepal width values.")

sepal_length = iris_df["SepalLengthCm"].unique()
print("There are",len(sepal_length),"unique sepal length values.")
# Out:
# There are 22 unique petal width values.
# There are 43 unique petal lenght values.
# There are 23 unique sepal width values.
# There are 35 unique sepal length values.

# %% [markdown]
# ### Box Plot

# %%
# Box Plot of Sepal Leangth
sns.boxplot(x="Species",y="SepalLengthCm",data=iris_df);

# %%
# box plot of Sepal Width
sns.boxplot(x="Species",y="SepalWidthCm",data=iris_df);

# %%
# Box plot of Petal Length
sns.boxplot(x="Species",y="PetalLengthCm",data=iris_df);

# %%
# Box plot of Petal Width
sns.boxplot(x="Species",y="PetalWidthCm",data=iris_df);

# %% [markdown]
# ### Distribution Graph

# %%
# Distribution graph
    
fig, ax = plt.subplots(2, 2, figsize=(10, 10))

sns.histplot(ax=ax[0,0],data=iris_df["PetalLengthCm"],kde=True)
ax[0,0].set_title("Distribution of PetalLength")


sns.histplot(ax=ax[0,1],data=iris_df["PetalWidthCm"],kde=True)
ax[0,1].set_title("Distribution of PetalWidth")


sns.histplot(ax=ax[1,0],data=iris_df["SepalLengthCm"],kde=True)
ax[1,0].set_title("Distribution of SepalLength")


sns.histplot(ax=ax[1,1],data=iris_df["SepalWidthCm"],kde=True)
ax[1,1].set_title("Distribution of SepalWidth")
# Out:
# Text(0.5, 1.0, 'Distribution of SepalWidth')

# %% [markdown]
# ### Box Plot of individual atributes

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 10))

sns.boxplot(ax=ax[0,0], x='SepalLengthCm', data=iris_df)

sns.boxplot(ax=ax[0,1], x='SepalWidthCm', data=iris_df)

sns.boxplot(ax=ax[1,0], x='PetalLengthCm', data=iris_df)

sns.boxplot(ax=ax[1,1], x='PetalWidthCm', data=iris_df)
# Out:
# <AxesSubplot: xlabel='PetalWidthCm'>

# %% [markdown]
# ### Four outliers are present in Sepal Width

# %%
# Remove outliers from Sepal width

q1 = iris_df['SepalWidthCm'].quantile(0.25)
q3 = iris_df['SepalWidthCm'].quantile(0.75) 
iq_range = q3 - q1
iris_df = iris_df[(iris_df['SepalWidthCm'] >= q1-1.5*iq_range) & (iris_df['SepalWidthCm'] <= q3+1.5*iq_range)]

# %%
# Box plot of sepal Width after outlier treatment
sns.boxplot(x='SepalWidthCm', data=iris_df)
# Out:
# <AxesSubplot: xlabel='SepalWidthCm'>

# %%
# No. of rows and columns after outlier treatment
iris_df.shape
# Out:
# (143, 5)

# %% [markdown]
# ### Correlation

# %%
# Correlation between attributes
corr = iris_df.corr()
corr
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.113268       0.879015      0.821715
# SepalWidthCm       -0.113268      1.000000      -0.396539     -0.328102
# PetalLengthCm       0.879015     -0.396539       1.000000      0.960785
# PetalWidthCm        0.821715     -0.328102       0.960785      1.000000

# %%
# Heat map of correlations
mask = np.triu(np.ones_like(corr, dtype=np.bool)) 
fig = plt.subplots(figsize=(10, 7))
sns.heatmap(iris_df.corr(), annot=True,fmt='.2f', mask=mask, cmap="crest")
plt.show()

# %% [markdown]
# ###  Scatter Plot

# %%
# 3D scatter plot

ax = plt.axes(projection ="3d")

df1 = iris_df[iris_df['Species']=='Iris-setosa']
df2 = iris_df[iris_df['Species']=='Iris-versicolor']
df3 = iris_df[iris_df['Species']=='Iris-virginica']

ax.scatter3D(df1["PetalLengthCm"], df1["PetalWidthCm"], df1["SepalLengthCm"], color = "violet",label="setosa")
ax.scatter3D(df2["PetalLengthCm"], df2["PetalWidthCm"], df2["SepalLengthCm"], color = "aqua",label="virginica")
ax.scatter3D(df3["PetalLengthCm"], df3["PetalWidthCm"], df3["SepalLengthCm"], color = "lime",label="versicolor")
ax.set_xlabel("Petal length")
ax.set_ylabel("Petal width")
ax.set_zlabel("Sepal Length")
plt.legend()
plt.title("simple 3D scatter plot")
# Out:
# Text(0.5, 0.92, 'simple 3D scatter plot')

# %% [markdown]
# ### Pair Plots

# %%
sns.pairplot(iris_df, corner=True)
plt.show()

# %%
sns.set_style('whitegrid')
sns.pairplot(iris_df, hue='Species', corner=True)
plt.show()

# %% [markdown]
# ###  Label Encoding

# %%
# Encode species value(i.e. object) to integers
L_encoder=LabelEncoder()
## Assingning encoded integer values to "Species" column
iris_df["Species"]=L_encoder.fit_transform(iris_df["Species"])
iris_df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %% [markdown]
# ### Data Preparation

# %%
# Seprate data into Attributes and labels
X=iris_df.iloc[:,:-1]
label=iris_df.iloc[:,-1]

# %%
# Split data for Training(80%) and Testing(20%)
X_train, X_test, train_labels, test_labels = train_test_split(X, label, test_size=0.2, random_state=1)

# %%
# Shape of splited data
print('X_train',X_train.shape)
print('X_test',X_test.shape)
print('train_labels',train_labels.shape)
print('test_labels',test_labels.shape)
# Out:
# X_train (114, 4)
# X_test (29, 4)
# train_labels (114,)
# test_labels (29,)

# %% [markdown]
# ### Training the Algorithm

# %%
dt_clf = DecisionTreeClassifier(criterion = 'gini' )
dt_clf.fit(X_train, train_labels)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### Testing algorithm with test data

# %%
# Prediction with test data
pred = dt_clf.predict(X_test)

# %% [markdown]
# ### Evaluating the model

# %%
# Accuracy of the model for test data
print("The accuracy of the model is", accuracy_score(pred,test_labels) *100,"%")
# Out:
# The accuracy of the model is 100.0 %

# %% [markdown]
# ### Testing algorithm with own values

# %%
## Predicting with random values
pred1=dt_clf.predict([[6,4,1,3]])
pred1
# Out:
# array([0])

# %% [markdown]
# ### Cunfusion Matrix

# %%
# Confusion Matrix of test labels and predicted labels
C_matrix=confusion_matrix(test_labels , pred)
C_matrix
# Out:
# array([[11,  0,  0],
#        [ 0, 12,  0],
#        [ 0,  0,  6]], dtype=int64)

# %%
# Heat map of confusion matrix

cm_df = pd.DataFrame(C_matrix, columns=np.unique(test_labels), index = np.unique(test_labels))
cm_df.index.name = 'Actual'
cm_df.columns.name= 'Predicted'
sns.heatmap(cm_df, cmap = "crest", annot=True) ;

# %% [markdown]
# ### Visualize the model

# %%
# Decision Tree Visualization
plt.figure(figsize=(15,10))
tree = plot_tree(dt_clf, feature_names=iris_df.columns, rounded=True, filled=True, class_names=True, fontsize=11)

# %% [markdown]
# ### Thank you
